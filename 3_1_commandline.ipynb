# %% [markdown]
# # Command line

# %% [markdown]
# The command line is a way to communicate with your computer.
# A "command" is an instruction.
#
# In macbook computers, the command line runs under an application called the "Terminal".
#
# ### What types of things can I do with a command?
#
# Lots of things:
# * Copy files
# * Move files from one folder to another
# * Make new folders
# * List all the files in a folder
# * Print the directory where you currently are
#
# ### What does a command look like?
#
# The first word is the "command", in other words the action that you want the computer to take. Most commands also take arguments, which you can pass to the computer as the second, third, etc word.
#
# ### First things first
#
# Open the Terminal application in your macbook.
#
# ### Changing directories
#
# You can use the cd command to Change Directories (change folders), pwd to Print the Working Directory and ls to LiSt the files and folders inside the folder where you are currently located.
#
# Type the following in the command line. What happens?
# * pwd
#
#
# Type the following in the command line. What happens?
# * ls
#
# Type the following. What happens?
# * cd
#
# Type the first line, hit ENTER, then type the second line and hit ENTER. What happens?
# * cd Desktop/
# * pwd
#
# Type the first line, hit ENTER, then type the second line and hit ENTER. What happens?
# * cd ../Downloads
# * pwd
#
#
# Notice, the cd command stands for "change directory". So that command helps to move to different directories. The second word after cd tells you what directory to move to. You can only move to a folder inside the folder where you are. For example, let's assume that you are in your home directory, which has the following two folders inside:
#
# * Desktop
# * Downloads
#
# If you wanted to go to the Desktop folder, you would have to type *cd Desktop/* in the Terminal.
#
# Let's assume you are now inside the desktop folder. If you wanted to go up one folder to your home folder, you would have to run the following command *cd ..* (don't forget to include the two dots at the end).
#
# ##### Exercise
#
# Go to the nsbp-summer-2022/ folder using the cd command.
#
# ### Copying files
#
# You can use the *cp* command to copy a file from one directory to another.
#
# In the terminal, make sure you are in the nsbp-summer-2022/ folder. To check this, type *pwd* and hit ENTER in the terminal. The *pwd* command Prints the Working Directory, in other words, the directory in which you are currently located. Once you have checked you are in the nsbp-summer-2022/ folder, and enter the following commands one at a time
#
# * cp test.txt ../
#
# * cd ..
#
# * ls
#
# What do you observe? You should see that the *cp* command created a copy of the test.txt file and copied it to the folder where the nsbp-summer-2022/ folder is located. The *cp* command takes in two arguments: the name of the file you want to copy and the path to the folder where you want to put the copy of the file.
#
# * cp file_to_copy path_to_destination_directory/
#
# ##### Exercise
#
# First, go to the Desktop/ folder from wherever you are in the terminal. Type pwd in the terminal so that you can see the full path to the Desktop/ folder
#
# Go to the nsbp_summer_2022/ folder (again, you can check if you are in the right directory by typing *pwd*, and you can also use *ls* to list the folders or files inside the folder where you are currently in). Copy the test.txt file to the Desktop/ folder.
#
# *Hint: You have to use the full path to the Desktop/ folder.*
#
# ### Moving files between directories
#
# You can use th mv command to move a file or a folder to another location. Notice, this is not the same as copying the file. Go to the Desktop/ folder in the terminal. Enter the following commands once at a time and notice what happens:
#
# * ls
#
# * mv test.txt ../Documents/
#
# * ls
#
# * cd ../Documents/
#
# * ls
#
# What did you see? You should see that initially you had a test.txt file inside the Desktop/ folder, and then you moved it to the Documents/ folder. Thus, the test.txt file now lives inside the Documents/ folder and no longer in the Desktop/ folder.
#
# Like the *cp* command, the *mv* command takes in two arguments, the name of the file you want to move and the path to the destination folder:
#
# * cp file_to_move path_to_destination_directory/
#
#
# ##### Exercise
#
# Go to the Documents/ folder, where you should now have the test.txt file (check this by typing *ls* inside the Documents/ folder). Move the test.txt file to the Downloads/ folder.
#
# ### Renaming files
#
# This part is confusing! It turns out that you can also use the *mv* command to rename files! Go to the Downloads/ folder and enter the following commands one by one:
#
# * ls
#
# * mv test.txt test2.txt
#
# * ls
#
# What happens? Notice that you just renamed the test.txt file to test2.txt.
#
# ##### Exercise
#
# Inside the Documents/ folder, rename the test2.txt file hello_world.txt.
